# %% [markdown]
# # SVD decomposition with `scipy`

# %% [markdown]
# Import the required modules

# %%
import scipy.linalg as la
import numpy as np

# %% [markdown]
# Generate a random 5x4 matrix

# %%
A = np.random.rand(5,4)
A
# Out:
# array([[0.52902229, 0.46502903, 0.58652354, 0.35140033],
#        [0.82581306, 0.97520609, 0.1126152 , 0.26095724],
#        [0.44528833, 0.29194349, 0.82532593, 0.96470703],
#        [0.88688653, 0.23529412, 0.24321327, 0.17809052],
#        [0.17334783, 0.47111925, 0.78251914, 0.00882002]])

# %% [markdown]
# ## `<numpy|scipy>.linalg.svd`
#
# Equivalent implementations:
# - https://numpy.org/doc/stable/reference/generated/numpy.linalg.svd.html
# - https://docs.scipy.org/doc/scipy/reference/generated/scipy.linalg.svd.html

# %% [markdown]
# ### Full SVD (`full_matrices = True` - default)
#
# **input:**
#
# $A \in \mathbb{R}^{m\times n}$
#
# **output:**
#
# $U \in \mathbb{R}^{m\times m}, S \in \mathbb{R}^{m\times n}, V \in \mathbb{R}^{n\times n}$
#
# or, more precisely
#
# $\boldsymbol{\sigma} \in \mathbb{R}^{q} $
#
# where $q = \min(m,n)$.

# %%
U, s, VT = np.linalg.svd(A)
# U, s, VT = la.svd(A)
print('U shape: ', U.shape)
print('s shape: ', s.shape)
print('VT shape: ', VT.shape)
# Out:
# U shape:  (5, 5)
# s shape:  (4,)
# VT shape:  (4, 4)

# %% [markdown]
# but s is an array

# %%
s
# Out:
# array([2.21287439, 0.945967  , 0.62824165, 0.42846405])

# %% [markdown]
# Build the matrix $S$

# %%
S = np.zeros(A.shape)
for i in range(len(s)):
    S[i, i] = s[i]
S
# Out:
# array([[2.21287439, 0.        , 0.        , 0.        ],
#        [0.        , 0.945967  , 0.        , 0.        ],
#        [0.        , 0.        , 0.62824165, 0.        ],
#        [0.        , 0.        , 0.        , 0.42846405],
#        [0.        , 0.        , 0.        , 0.        ]])

# %%
S = la.diagsvd(s, A.shape[0], A.shape[1])
S
# Out:
# array([[2.52842492, 0.        , 0.        , 0.        ],
#        [0.        , 0.72715521, 0.        , 0.        ],
#        [0.        , 0.        , 0.28591845, 0.        ],
#        [0.        , 0.        , 0.        , 0.21149482],
#        [0.        , 0.        , 0.        , 0.        ]])

# %% [markdown]
# Reconstruct the matrix $A$

# %%
A_svd = np.matmul(U, np.matmul(S,VT))
print('err: %e' % (la.norm(A - A_svd) / la.norm(A)))
# Out:
# err: 1.959858e-15

# %% [markdown]
# ### Thin SVD (`full_matrices = False`)
#
# **input:**
#
# $A \in \mathbb{R}^{m\times n}$
#
# **output:**
#
# $U \in \mathbb{R}^{m\times q}, S \in \mathbb{R}^{q\times q}, V \in \mathbb{R}^{n\times q}$
#
# or, more precisely
#
# $\boldsymbol{\sigma} \in \mathbb{R}^{q} $
#
# where $q = \min(m,n)$.

# %%
# del U, s, S, VT
U, s, VT = la.svd(A, full_matrices = False)
print('U shape: ', U.shape)
print('s shape: ', s.shape)
print('VT shape: ', VT.shape)
# Out:
# U shape:  (5, 4)
# s shape:  (4,)
# VT shape:  (4, 4)

# %% [markdown]
# Build the matrix $S$

# %%
S = np.diag(s)
S
# Out:
# array([[2.21287439, 0.        , 0.        , 0.        ],
#        [0.        , 0.945967  , 0.        , 0.        ],
#        [0.        , 0.        , 0.62824165, 0.        ],
#        [0.        , 0.        , 0.        , 0.42846405]])

# %% [markdown]
# Reconstruct the matrix $A$

# %%
A_svd = np.matmul(U, np.matmul(S,VT))
print('err: %e' % (la.norm(A - A_svd) / la.norm(A)))
# Out:
# err: 1.959858e-15
