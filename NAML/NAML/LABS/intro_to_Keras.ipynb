# %% [markdown]
# # An introduction to Keras
#
# <div align="center">
#   <img src="https://keras.io/img/logo.png">
# </div>
#
# [Keras](https://keras.io/) is an open-source software library that provides a Python interface for artificial neural networks. Keras acts as an interface for the TensorFlow library.
# Up until version 2.3 Keras supported multiple backends, including TensorFlow, Microsoft Cognitive Toolkit, R, Theano, and PlaidML. As of version 2.4, only TensorFlow is supported. Designed to enable fast experimentation with deep neural networks, it focuses on being user-friendly, modular, and extensible.
#
# It was developed as part of the research effort of project ONEIROS (Open-ended Neuro-Electronic Intelligent Robot Operating System), and its primary author and maintainer is François Chollet, a Google engineer.
#
#
# - Guide: see TensorFlow [Guide](https://www.tensorflow.org/guide) / Keras
# - Python API reference: see TensorFlow [Python API reference](https://www.tensorflow.org/api_docs/python/tf/keras)
# - [GitHub development repository](https://github.com/keras-team/keras), now migrated into TensorFlow [GitHub development repository](https://github.com/tensorflow/tensorflow)
# - [Code examples](https://keras.io/examples/)

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## MNIST benchmark with Keras

# %% [markdown]
# ### Preparing data
#
# Load [MNIST](https://en.wikipedia.org/wiki/MNIST_database) dataset. Notice that TensorFlow uses by default the first axes for samples/batches and the last ones for features.

# %%
data = np.genfromtxt('sample_data/mnist_train_small.csv', delimiter=',')
y_data = data[:,0]
x_data = data[:,1:] / 255
print(x_data.shape, "\n")
print(y_data.shape, "\n")
# Out:
# (20000, 784)
#
# (20000,)

# %% [markdown]
# Train-validation split.

# %%
n_train = 10000
n_valid = 10000
x_train = x_data[:n_train ,:]
y_train = y_data[:n_train]
x_valid = x_data[-n_valid:,:]
y_valid = y_data[-n_valid:]

# %% [markdown]
# ### ANN setup and training

# %% [markdown]
# We creare a fully connected ANN, with two 50-neuron hidden layers and a soft-max layer.

# %%
model = keras.Sequential([
    keras.layers.Dense(50, activation='tanh', input_shape=(784,)),
    keras.layers.Dense(50, activation='tanh'),
    keras.layers.Dense(10),
    keras.layers.Softmax()
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                39250
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 10)                510
#
#  softmax (Softmax)           (None, 10)                0
#
# =================================================================
# Total params: 42,310
# Trainable params: 42,310
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We compile the model (that is, we trace the computational graph by [Autograph](https://www.tensorflow.org/guide/intro_to_graphs)).

# %%
model.compile(optimizer = keras.optimizers.RMSprop(learning_rate=0.002,rho=0.9),
              loss = keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %% [markdown]
# We train the model.

# %%
model.fit(x_train, y_train, epochs = 50, validation_data = (x_valid, y_valid), batch_size=1000)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 67ms/step - loss: 1.3967 - accuracy: 0.5945 - val_loss: 0.8696 - val_accuracy: 0.7996
# Epoch 2/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.7529 - accuracy: 0.8151 - val_loss: 0.6112 - val_accuracy: 0.8540
# Epoch 3/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.5526 - accuracy: 0.8617 - val_loss: 0.4870 - val_accuracy: 0.8766
# Epoch 4/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.4565 - accuracy: 0.8771 - val_loss: 0.4466 - val_accuracy: 0.8793
# Epoch 5/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3972 - accuracy: 0.8894 - val_loss: 0.3830 - val_accuracy: 0.8935
# Epoch 6/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.3470 - accuracy: 0.9074 - val_loss: 0.3414 - val_accuracy: 0.9051
# Epoch 7/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.3188 - accuracy: 0.9101 - val_loss: 0.3325 - val_accuracy: 0.9064
# Epoch 8/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2874 - accuracy: 0.9196 - val_loss: 0.3152 - val_accuracy: 0.9069
# Epoch 9/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.2713 - accuracy: 0.9219 - val_loss: 0.3100 - val_accuracy: 0.9089
# Epoch 10/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2521 - accuracy: 0.9282 - val_loss: 0.2738 - val_accuracy: 0.9211
# Epoch 11/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2334 - accuracy: 0.9349 - val_loss: 0.2755 - val_accuracy: 0.9201
# Epoch 12/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.2279 - accuracy: 0.9372 - val_loss: 0.2769 - val_accuracy: 0.9197
# Epoch 13/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2128 - accuracy: 0.9391 - val_loss: 0.2601 - val_accuracy: 0.9231
# Epoch 14/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1913 - accuracy: 0.9470 - val_loss: 0.2513 - val_accuracy: 0.9260
# Epoch 15/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1864 - accuracy: 0.9469 - val_loss: 0.2472 - val_accuracy: 0.9284
# Epoch 16/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1789 - accuracy: 0.9502 - val_loss: 0.2454 - val_accuracy: 0.9280
# Epoch 17/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1641 - accuracy: 0.9540 - val_loss: 0.2365 - val_accuracy: 0.9315
# Epoch 18/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.1597 - accuracy: 0.9541 - val_loss: 0.2261 - val_accuracy: 0.9336
# Epoch 19/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1516 - accuracy: 0.9572 - val_loss: 0.2245 - val_accuracy: 0.9341
# Epoch 20/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1388 - accuracy: 0.9631 - val_loss: 0.2662 - val_accuracy: 0.9210
# Epoch 21/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.1350 - accuracy: 0.9646 - val_loss: 0.2344 - val_accuracy: 0.9302
# Epoch 22/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1276 - accuracy: 0.9643 - val_loss: 0.2165 - val_accuracy: 0.9355
# Epoch 23/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.1225 - accuracy: 0.9672 - val_loss: 0.2118 - val_accuracy: 0.9381
# Epoch 24/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1108 - accuracy: 0.9706 - val_loss: 0.2101 - val_accuracy: 0.9378
# Epoch 25/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.1127 - accuracy: 0.9700 - val_loss: 0.2157 - val_accuracy: 0.9371
# Epoch 26/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0993 - accuracy: 0.9740 - val_loss: 0.2071 - val_accuracy: 0.9388
# Epoch 27/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0979 - accuracy: 0.9736 - val_loss: 0.2296 - val_accuracy: 0.9296
# Epoch 28/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0929 - accuracy: 0.9737 - val_loss: 0.1991 - val_accuracy: 0.9420
# Epoch 29/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0897 - accuracy: 0.9762 - val_loss: 0.2085 - val_accuracy: 0.9380
# Epoch 30/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0817 - accuracy: 0.9787 - val_loss: 0.2727 - val_accuracy: 0.9176
# Epoch 31/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0793 - accuracy: 0.9791 - val_loss: 0.2052 - val_accuracy: 0.9400
# Epoch 32/50
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0752 - accuracy: 0.9810 - val_loss: 0.2131 - val_accuracy: 0.9368
# Epoch 33/50
# 10/10 [==============================] - 0s 22ms/step - loss: 0.0662 - accuracy: 0.9841 - val_loss: 0.1932 - val_accuracy: 0.9428
# Epoch 34/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0667 - accuracy: 0.9833 - val_loss: 0.2093 - val_accuracy: 0.9390
# Epoch 35/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0572 - accuracy: 0.9864 - val_loss: 0.2016 - val_accuracy: 0.9422
# Epoch 36/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0615 - accuracy: 0.9845 - val_loss: 0.2108 - val_accuracy: 0.9380
# Epoch 37/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0509 - accuracy: 0.9890 - val_loss: 0.2070 - val_accuracy: 0.9414
# Epoch 38/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0572 - accuracy: 0.9860 - val_loss: 0.2002 - val_accuracy: 0.9431
# Epoch 39/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0471 - accuracy: 0.9895 - val_loss: 0.2345 - val_accuracy: 0.9333
# Epoch 40/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0432 - accuracy: 0.9911 - val_loss: 0.2203 - val_accuracy: 0.9383
# Epoch 41/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0434 - accuracy: 0.9911 - val_loss: 0.2064 - val_accuracy: 0.9410
# Epoch 42/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0423 - accuracy: 0.9903 - val_loss: 0.1922 - val_accuracy: 0.9454
# Epoch 43/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0458 - accuracy: 0.9895 - val_loss: 0.2075 - val_accuracy: 0.9416
# Epoch 44/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0300 - accuracy: 0.9950 - val_loss: 0.2117 - val_accuracy: 0.9404
# Epoch 45/50
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0304 - accuracy: 0.9949 - val_loss: 0.2021 - val_accuracy: 0.9438
# Epoch 46/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.0298 - accuracy: 0.9947 - val_loss: 0.2163 - val_accuracy: 0.9402
# Epoch 47/50
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0329 - accuracy: 0.9927 - val_loss: 0.2199 - val_accuracy: 0.9398
# Epoch 48/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0269 - accuracy: 0.9957 - val_loss: 0.2328 - val_accuracy: 0.9345
# Epoch 49/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0288 - accuracy: 0.9947 - val_loss: 0.2132 - val_accuracy: 0.9433
# Epoch 50/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.0283 - accuracy: 0.9942 - val_loss: 0.2491 - val_accuracy: 0.9335

# %% [markdown]
# ### Testing
#
# We load testing data.

# %%
data_test = np.genfromtxt('sample_data/mnist_test.csv', delimiter=',')
y_test = data_test[:,0]
x_test = data_test[:,1:] / 255
print(x_test.shape, "\n")
print(y_test.shape, "\n")
# Out:
# (10000, 784)
#
# (10000,)

# %% [markdown]
# We evaluate the accuracy of the model in the test dataset.

# %%
predicted_probabilities = model.predict(x_test)
predicted_labels = tf.argmax(predicted_probabilities, axis=1)
accuracy_test = tf.reduce_mean(tf.cast(predicted_labels == y_test, tf.float32))
print('Accuracy (test dataset): %1.2f%%' % (accuracy_test * 100))
# Out:
# 313/313 [==============================] - 0s 1ms/step
# Accuracy (test dataset): 93.52%

# %% [markdown]
# Equivalent implementation (using the built-in metric).

# %%
accuracy_test = keras.metrics.SparseCategoricalAccuracy()(y_test, model.predict(x_test))
print('Accuracy (test dataset): %1.2f%%' % (accuracy_test * 100))
# Out:
# 313/313 [==============================] - 0s 1ms/step
# Accuracy (test dataset): 93.52%

# %% [markdown]
# ## Writing a custom training loop
#
# Keras adopts the principle of progressive disclosure of complexity: simple workflows should be quick and easy, while arbitrarily advanced workflows should be possible via a clear path that builds upon what you've already learned.

# %%
batch_size = 250
num_epochs = 20

optimizer = keras.optimizers.RMSprop(learning_rate=0.002,rho=0.9)
loss = keras.losses.SparseCategoricalCrossentropy()

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(784,)),
    keras.layers.Dense(50, activation='tanh'),
    keras.layers.Dense(50, activation='tanh'),
    keras.layers.Dense(10),
    keras.layers.Softmax()
])

dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))

for epoch in range(num_epochs):
  for (x_batch, y_batch) in dataset.batch(batch_size):
    with tf.GradientTape() as tape:
      y_predicted_batch = model(x_batch)
      current_loss = loss(y_batch, y_predicted_batch)
    gradients = tape.gradient(current_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

  accuracy_train = keras.metrics.SparseCategoricalAccuracy()(y_train, model.predict(x_train))
  accuracy_valid = keras.metrics.SparseCategoricalAccuracy()(y_valid, model.predict(x_valid))
  print('epoch %2d - accuracy: train %1.2f%%, valid %1.2f%%' % (epoch + 1, accuracy_train * 100, accuracy_valid * 100))
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  1 - accuracy: train 88.15%, valid 88.57%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  2 - accuracy: train 90.87%, valid 90.64%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  3 - accuracy: train 92.48%, valid 91.64%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  4 - accuracy: train 93.43%, valid 92.15%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  5 - accuracy: train 94.19%, valid 92.53%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  6 - accuracy: train 94.98%, valid 92.84%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  7 - accuracy: train 95.75%, valid 93.18%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  8 - accuracy: train 96.42%, valid 93.43%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch  9 - accuracy: train 96.90%, valid 93.70%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 10 - accuracy: train 97.42%, valid 93.90%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 11 - accuracy: train 97.90%, valid 94.00%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 12 - accuracy: train 98.26%, valid 94.01%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 13 - accuracy: train 98.64%, valid 94.06%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 14 - accuracy: train 98.96%, valid 94.21%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 15 - accuracy: train 99.19%, valid 94.21%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 16 - accuracy: train 99.38%, valid 94.46%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 17 - accuracy: train 99.57%, valid 94.55%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 18 - accuracy: train 99.72%, valid 94.57%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 19 - accuracy: train 99.21%, valid 94.15%
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# epoch 20 - accuracy: train 99.67%, valid 94.47%

# %%
print('Accuracy (train dataset)     : %1.2f%%' % (keras.metrics.SparseCategoricalAccuracy()(y_train, model.predict(x_train)) * 100))
print('Accuracy (validation dataset): %1.2f%%' % (keras.metrics.SparseCategoricalAccuracy()(y_valid, model.predict(x_valid)) * 100))
print('Accuracy (test dataset)      : %1.2f%%' % (keras.metrics.SparseCategoricalAccuracy()(y_test,  model.predict(x_test )) * 100))
# Out:
# 313/313 [==============================] - 0s 935us/step
# Accuracy (train dataset)     : 99.30%
# 313/313 [==============================] - 0s 1ms/step
# Accuracy (validation dataset): 94.47%
# 313/313 [==============================] - 0s 961us/step
# Accuracy (test dataset)      : 94.41%
